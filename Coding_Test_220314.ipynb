# %% [markdown]
# ### 셀프 넘버
# - 셀프 넘버는 1949년 인도 수학자 D.R. Kaprekar가 이름 붙였다. 양의 정수 n에 대해서 d(n)을 n과 n의 각 자리수를 더하는 함수라고 정의하자. 예를 들어, d(75) = 75+7+5 = 87이다.
#
# - 양의 정수 n이 주어졌을 때, 이 수를 시작해서 n, d(n), d(d(n)), d(d(d(n))), ...과 같은 무한 수열을 만들 수 있다.
#
# - 예를 들어, 33으로 시작한다면 다음 수는 33 + 3 + 3 = 39이고, 그 다음 수는 39 + 3 + 9 = 51, 다음 수는 51 + 5 + 1 = 57이다. 이런식으로 다음과 같은 수열을 만들 수 있다.
#
# - 33, 39, 51, 57, 69, 84, 96, 111, 114, 120, 123, 129, 141, ...
#
# - n을 d(n)의 생성자라고 한다. 위의 수열에서 33은 39의 생성자이고, 39는 51의 생성자, 51은 57의 생성자이다. 생성자가 한 개보다 많은 경우도 있다. 예를 들어, 101은 생성자가 2개(91과 100) 있다.
#
# - 생성자가 없는 숫자를 셀프 넘버라고 한다. 100보다 작은 셀프 넘버는 총 13개가 있다. 1, 3, 5, 7, 9, 20, 31, 42, 53, 64, 75, 86, 97
#
# - 10000보다 작거나 같은 셀프 넘버를 한 줄에 하나씩 출력하는 프로그램을 작성하시오.

# %%
# 생성자인 값들을 1~10000사이에서 빼주고 출력하는 로직

# %%
number = [i for i in range(1,10001)]

# %%
not_number = [] 
for i in range(1, 10001):
    s = ""
    for j in str(i):
        i += int(j)
        # s = i 
        # 이거 없어도 되네 
    not_number.append(i)
a = set(number) - set(not_number)

for i in sorted(a):
    print(i)
# 정답 
# 근데 조금 많이 지저분하네...
# Out:
# 1
# 3
# 5
# 7
# 9
# 20
# 31
# 42
# 53
# 64
# 75
# 86
# 97
# 108
# 110
# 121
# 132
# 143
# 154
# 165
# 176
# 187
# 198
# 209
# 211
# 222
# 233
# 244
# 255
# 266
# 277
# 288
# 299
# 310
# 312
# 323
# 334
# 345
# 356
# 367
# 378
# 389
# 400
# 411
# 413
# 424
# 435
# 446
# 457
# 468
# 479
# 490
# 501
# 512
# 514
# 525
# 536
# 547
# 558
# 569
# 580
# 591
# 602
# 613
# 615
# 626
# 637
# 648
# 659
# 670
# 681
# 692
# 703
# 714
# 716
# 727
# 738
# 749
# 760
# 771
# 782
# 793
# 804
# 815
# 817
# 828
# 839
# 850
# 861
# 872
# 883
# 894
# 905
# 916
# 918
# 929
# 940
# 951
# 962
# 973
# 984
# 995
# 1006
# 1021
# 1032
# 1043
# 1054
# 1065
# 1076
# 1087
# 1098
# 1109
# 1111
# 1122
# 1133
# 1144
# 1155
# 1166
# 1177
# 1188
# 1199
# 1210
# 1212
# 1223
# 1234
# 1245
# 1256
# 1267
# 1278
# 1289
# 1300
# 1311
# 1313
# 1324
# 1335
# 1346
# 1357
# 1368
# 1379
# 1390
# 1401
# 1412
# 1414
# 1425
# 1436
# 1447
# 1458
# 1469
# 1480
# 1491
# 1502
# 1513
# 1515
# 1526
# 1537
# 1548
# 1559
# 1570
# 1581
# 1592
# ...

# %%
num = set(range(1,10001))
rmv = set()
for i in range (1,10001):
    for j in str(i):
        i += int(j)
    rmv.add(i)
num = num - rmv
for k in sorted(num):
    print(k)
# 다른 사람풀이
# Out:
# 1
# 3
# 5
# 7
# 9
# 20
# 31
# 42
# 53
# 64
# 75
# 86
# 97
# 108
# 110
# 121
# 132
# 143
# 154
# 165
# 176
# 187
# 198
# 209
# 211
# 222
# 233
# 244
# 255
# 266
# 277
# 288
# 299
# 310
# 312
# 323
# 334
# 345
# 356
# 367
# 378
# 389
# 400
# 411
# 413
# 424
# 435
# 446
# 457
# 468
# 479
# 490
# 501
# 512
# 514
# 525
# 536
# 547
# 558
# 569
# 580
# 591
# 602
# 613
# 615
# 626
# 637
# 648
# 659
# 670
# 681
# 692
# 703
# 714
# 716
# 727
# 738
# 749
# 760
# 771
# 782
# 793
# 804
# 815
# 817
# 828
# 839
# 850
# 861
# 872
# 883
# 894
# 905
# 916
# 918
# 929
# 940
# 951
# 962
# 973
# 984
# 995
# 1006
# 1021
# 1032
# 1043
# 1054
# 1065
# 1076
# 1087
# 1098
# 1109
# 1111
# 1122
# 1133
# 1144
# 1155
# 1166
# 1177
# 1188
# 1199
# 1210
# 1212
# 1223
# 1234
# 1245
# 1256
# 1267
# 1278
# 1289
# 1300
# 1311
# 1313
# 1324
# 1335
# 1346
# 1357
# 1368
# 1379
# 1390
# 1401
# 1412
# 1414
# 1425
# 1436
# 1447
# 1458
# 1469
# 1480
# 1491
# 1502
# 1513
# 1515
# 1526
# 1537
# 1548
# 1559
# 1570
# 1581
# 1592
# ...

# %% [markdown]
# ### 한수
# - 어떤 양의 정수 X의 각 자리가 등차수열을 이룬다면, 그 수를 한수라고 한다. 등차수열은 연속된 두 개의 수의 차이가 일정한 수열을 말한다. N이 주어졌을 때, 1보다 크거나 같고, N보다 작거나 같은 한수의 개수를 출력하는 프로그램을 작성하시오.
# - 첫째 줄에 1,000보다 작거나 같은 자연수 N이 주어진다.

# %%
# 입력받은 값 1부터 반복 
# 각 값이 등차수열인지 확인 
# 확인 후 등차수열이면 count
# 질문검색으로 확인한 결과 100까지는 모두 한수 
# 100번 이후부터 체크  
n = int(input())

# %%
cnt = 0 
for i in range(1, n+1):
    if i < 100:
        cnt += 1 
    else:
        k = str(i)
        for j in range(len(k)):
            if int(k[1]) - int(k[0]) == int(k[1]) - int(k[2]):
                # 이게 한수이지 않을까?
                # 각 자리수가 일정하다는 뜻으로
                cnt += 1 
            else:
                pass
                    
    
print(cnt)
# 정답이 아니네...
# Out:
# 219

# %%
cnt = 0 
for i in range(1, n+1):
    if i < 100:
        cnt += 1 
    else:
        k = str(i)
        if int(k[1]) - int(k[0]) == int(k[2]) - int(k[1]):
            # 이게 한수이지 않을까?
            # 각 자리수가 일정하다는 뜻으로
            cnt += 1 
        
                    
    
print(cnt)
# 정답 
# for문을 두번써서 중첩으로 count된 것 같음
# Out:
# 119

# %%
# 다른 사람 풀이 
def hansu(num) :
    hansu_cnt = 0
    for i in range(1, num+1):
        num_list = list(map(int,str(i)))
        if i < 100:
            hansu_cnt += 1  # 100보다 작으면 모두 한수
        elif num_list[0]-num_list[1] == num_list[1]-num_list[2]:
            hansu_cnt += 1  # x의 각 자리가 등차수열이면 한수
    return hansu_cnt

num = int(input())
print(hansu(num))
# Out:
# 99

# %% [markdown]
# ### 베르트랑 공준
# - 베르트랑 공준은 임의의 자연수 n에 대하여, n보다 크고, 2n보다 작거나 같은 소수는 적어도 하나 존재한다는 내용을 담고 있다.
#
# - 이 명제는 조제프 베르트랑이 1845년에 추측했고, 파프누티 체비쇼프가 1850년에 증명했다.
#
# - 예를 들어, 10보다 크고, 20보다 작거나 같은 소수는 4개가 있다. (11, 13, 17, 19) 또, 14보다 크고, 28보다 작거나 같은 소수는 3개가 있다. (17,19, 23)
#
# - 자연수 n이 주어졌을 때, n보다 크고, 2n보다 작거나 같은 소수의 개수를 구하는 프로그램을 작성하시오.

# %%
# 주어진 숫자 n을 받아서 반복문 돌려서 소수구하기 
# 구한 소수 개수 출력 
n = 13

# %%
cnt = 0
for i in range(n+1, (n*2)+1):
    error = 0
    for j in range(2,i):
        if i % j == 0:
            error += 1 
    if error == 0:
        cnt += 1 
# print(len(set(a)))
# print(set(a))
print(cnt)
# Out:
# 3

# %%
while True:
    n = int(input())
    if n == 0:
        break

    cnt = 0
    if n == 1:
        print(1)
    elif n >= 2:
    
        for i in range(n+1, (n*2)+1):
            error = 0
            for j in range(2,i):
                if i % j == 0:
                    error += 1 
            if error == 0:
                cnt += 1 
        
        print(cnt)
# 시간초과
# Out:
# 1
# 4
# 3
# 21
# 135
# 1033
# 8392

# %%
while True:
    n = int(input())
    if n == 0:
        break

    cnt = 0
    if n == 1:
        print(1)
    elif n >= 2:
    
        for i in range(n+1, (n*2)+1):
            error = 0
            for j in range(2,int(i**0.5)+1):
                # 어제 풀었던 소수 시간 초과났던 문제를 참조해서 소수가 아닌 것의 특징인 대칭을 이용 
                if i % j == 0:
                    error += 1 
            if error == 0:
                cnt += 1 
        
        print(cnt)
# 이것도 시간초과
# Out:
# 1
# 4
# 3
# 21
# 135
# 1033
# 8392

# %%
while True:
    n = int(input())
    if n == 0:
        break

    cnt = 0
    if n == 1:
        print(1)
    elif n >= 2:
    
        for i in range(n+1, (n*2)+1):
            error = 0
            for j in range(2,int(i**0.5)+1):
                # 어제 풀었던 소수 시간 초과났던 문제를 참조해서 소수가 아닌 것의 특징인 대칭을 이용 
                if i % j == 0:
                    break 
            else: 
                cnt += 1 
        
        print(cnt)
# 이것도 시간초과...
# Out:
# 1
# 4
# 3
# 21
# 135

# %%
# 시간초과를 해결하지 못해 다른 사람 풀이 참조 
def sosu(n):
    if n ==1:
        return False
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            return False
    return True							
# 소수를 구하는 메소드

all_list = list(range(2,246912))
# 문제에서 제한한 범위를 미리 지정 
memo = []								
# for문 밖에 리스트 정의

for i in all_list:						
    if sosu(i):							
        #sosu함수에 해당하면
        memo.append(i)					
        #리스트에 추가

n = int(input())

while True:
    count=0					
    #갯수를 세야하는 조건 때문에 카운트
    if n == 0 :
            break
    for i in memo:			
        #memo리스트 중에서
        if n < i <=2*n:		
            #입력한 값의 범위 내에서 값이 있으면
            count+=1		
            #있을 때 마다 카운트 +1
    print(count)
    n = int(input())		
    #0 입력받기 전까지 계속 해야하므로 입력 받음

# 소수를 판별하는 메소드를 미리 지정하고 문제의 범위에 맞게 미리 소수를 추출 
# 추출한 것을 바탕으로 입력 범위안의 소수 개수 출력 
# 이제부터 시간초과가 뜨면 메소드를 지정해서 풀어봐야겠다
# Out:
# 1
# 4
# 3
# 21
# 135

# %% [markdown]
# ### 터렛
# - 조규현과 백승환은 터렛에 근무하는 직원이다. 하지만 워낙 존재감이 없어서 인구수는 차지하지 않는다. 다음은 조규현과 백승환의 사진이다.
#
# - 이석원은 조규현과 백승환에게 상대편 마린(류재명)의 위치를 계산하라는 명령을 내렸다. 조규현과 백승환은 각각 자신의 터렛 위치에서 현재 적까지의 거리를 계산했다.
#
# - 조규현의 좌표 (x1, y1)와 백승환의 좌표 (x2, y2)가 주어지고, 조규현이 계산한 류재명과의 거리 r1과 백승환이 계산한 류재명과의 거리 r2가 주어졌을 때, 류재명이 있을 수 있는 좌표의 수를 출력하는 프로그램을 작성하시오.
#
# - 첫째 줄에 테스트 케이스의 개수 T가 주어진다. 각 테스트 케이스는 다음과 같이 이루어져 있다.
#
# - 한 줄에 x1, y1, r1, x2, y2, r2가 주어진다. x1, y1, x2, y2는 -10,000보다 크거나 같고, 10,000보다 작거나 같은 정수이고, r1, r2는 10,000보다 작거나 같은 자연수이다.

# %%
"""
- 피타고라스정리를 응용
- 류재명이 있을만한 점 : (x,y)
- 이석원과 류재명 거리 : (x-0)**2 + (y-0)**2 = 13 
- 백승환과 류재명 거리 : (x-40)**2 + (y-0)**2 = 37
- 류재명이 있을만한 점 : (19.5375,0), (-19.5375,0)
- 답이 있으면 count 없으면 0 무한대면 -1 
- 값을 구했을때 각 위치에서 -나 +를 붙였을때에도 똑같은 거리인지 판단해보기 
"""
# 어 그러면 류재명의 위치는 소수점이 나오는 좌표인데 이거 가능한건가?
# 이거는 다시 생각해보기
# Out:
# '\n- 피타고라스정리를 응용\n- 류재명이 있을만한 점 : (x,y)\n- 이석원과 류재명 거리 : (x-0)**2 + (y-0)**2 = 13 \n- 백승환과 류재명 거리 : (x-40)**2 + (y-0)**2 = 37\n- 류재명이 있을만한 점 : (19.5375,0), (-19.5375,0)\n- 답이 있으면 count 없으면 0 무한대면 -1 \n'
